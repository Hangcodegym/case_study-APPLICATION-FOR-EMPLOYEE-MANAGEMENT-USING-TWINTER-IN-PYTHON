# %%
import tkinter as tk
from tkinter import ttk
from tkinter.filedialog import asksaveasfile
from tkinter import messagebox
root=tk.Tk()
root.title('Employee Database')
root.geometry('1500x800')

def add_employee():  
    Employee_ID=var1.get() 
    First_name=var2.get() 
    Last_name=var3.get()
    Department=var4.get()
    Place_of_origin= var5.get()
    Date_of_birth= var6.get()
    Phone_number= var7.get()
    Start_date= var8.get()
    End_date=var9.get()
    trv.insert("","end", values=(Employee_ID, First_name,Last_name,Department, Place_of_origin, Date_of_birth, \
                                 Phone_number,Start_date,End_date))
    # Clear entry boxes
    Entry1.delete(0, tk.END)
    Entry2.delete(0, tk.END)
    Entry3.delete(0, tk.END)
    Entry4.delete(0, tk.END)
    Entry5.delete(0, tk.END)
    Entry6.delete(0, tk.END)
    Entry7.delete(0, tk.END)
    Entry8.delete(0, tk.END)
    Entry9.delete(0, tk.END)    
    
def update_employee():    
    selected = trv.focus()
    trv.item(selected, text="", values=(Entry1.get(), Entry2.get(), Entry3.get(),Entry4.get(), Entry5.get(),\
                                        Entry6.get(), Entry7.get(), Entry8.get(),Entry9.get()))
      # Clear entry boxes
    Entry1.delete(0, tk.END)
    Entry2.delete(0, tk.END)
    Entry3.delete(0, tk.END)
    Entry4.delete(0, tk.END)
    Entry5.delete(0, tk.END)
    Entry6.delete(0, tk.END)
    Entry7.delete(0, tk.END)
    Entry8.delete(0, tk.END)
    Entry9.delete(0, tk.END)
    
def delete_employee():
     # Get 1 selected item to Delete
    selected_item = trv.selection()[0]
    trv.delete(selected_item)
      # Clear entry boxes
    Entry1.delete(0, tk.END)
    Entry2.delete(0, tk.END)
    Entry3.delete(0, tk.END)
    Entry4.delete(0, tk.END)
    Entry5.delete(0, tk.END)
    Entry6.delete(0, tk.END)
    Entry7.delete(0, tk.END)
    Entry8.delete(0, tk.END)
    Entry9.delete(0, tk.END)
    
def Search ():
    pass
def clear ():
    pass

def show_entries():
# Grab record Number
    selected = trv.focus()
# Grab record values
    values = trv.item(selected, 'values')
# outpus to entry boxes
    Entry1.insert(0, values[0])
    Entry2.insert(0, values[1])
    Entry3.insert(0, values[2])
    Entry4.insert(0, values[3])
    Entry5.insert(0, values[4])
    Entry6.insert(0, values[5])
    Entry7.insert(0, values[6])
    Entry8.insert(0, values[7])
    Entry9.insert(0, values[8])
# Clear entry boxes
def clear_entries():
    Entry1.delete(0, tk.END)
    Entry2.delete(0, tk.END)
    Entry3.delete(0, tk.END)
    Entry4.delete(0, tk.END)
    Entry5.delete(0, tk.END)
    Entry6.delete(0, tk.END)
    Entry7.delete(0, tk.END)
    Entry8.delete(0, tk.END)
    Entry9.delete(0, tk.END)
    
# create Stringvar for entry widget    
var0=tk.StringVar(root)
var1=tk.StringVar(root)
var2=tk.StringVar(root)
var3=tk.StringVar(root)
var4=tk.StringVar(root)
var5=tk.StringVar(root)
var6=tk.StringVar(root)
var7=tk.StringVar(root)
var8=tk.StringVar(root)
var9=tk.StringVar(root)

# make wrapper
wrapper1=tk.LabelFrame(root, text='Employee List')
wrapper2=tk.LabelFrame(root, text='Search')
wrapper3=tk.LabelFrame(root, text='Arrange')
wrapper4=tk.LabelFrame(root, text=' Employee Data')
wrapper1.pack(fill='both', expand='Yes', padx=20, pady=10)
wrapper2.pack(fill='both', expand='Yes', padx=20, pady=10)
wrapper3.pack(fill='both', expand='Yes', padx=20, pady=10)
wrapper4.pack(fill='both', expand='Yes', padx=20, pady=10)

# create Treeview frame for wrapper 1
trv=ttk.Treeview(wrapper1, columns=(1,2,3,4,5,6,7,8,9), show ='headings', height='15', selectmode='browse')
trv.pack()

# Create a Treeview Scrollbar
# tree_scroll = Scrollbar(trv)
# tree_scroll.pack(side=RIGHT, fill=Y)
# tree_scroll.config(command=trv.yview)

# Format Columns
trv.column(1, anchor ='c',  width = 100)
trv.column(2, anchor ='c',  width = 160)
trv.column(3, anchor ='c',  width = 160)
trv.column(4, anchor ='c',  width = 160)
trv.column(5, anchor ='c',  width = 160)
trv.column(6, anchor ='c',  width = 160)
trv.column(7, anchor ='c',  width = 160)
trv.column(8, anchor ='c',  width = 160)
trv.column(9, anchor ='c',  width = 160)

# Create Headings
trv.heading(1, text='Employee ID')
trv.heading(2, text='First name')
trv.heading(3, text='Last name')
trv.heading(4, text='Department')
trv.heading(5, text='Place of origin')
trv.heading(6, text='Date of birth')
trv.heading(7, text='Phone number')
trv.heading(8, text='Start date')
trv.heading(9, text='End date')

trv.insert("",'end', values=('PF00018','NGUYỄN THANH','HIỀN ','Production', 'Binh Duong ', ' 6/23/1995', \
                             '0963257022', ' 6/23/1995', ' 4/10/2020', ))
trv.insert("",'end', values=('PF00020','TÔ THÙY THANH','THẢO ','Production', 'Binh Duong ', ' 5/13/1992', \
                             '0355375662', ' 6/23/1995', ' 4/10/2020', ))
trv.insert("",'end', values=('PF00016','NGUYỄN THỊ NGỌC','ĐIỆP ','Production', 'HCM ', ' 8/15/1991', \
                             '0962457022', ' 5/8/2020', ' 6/8/2020', ))
trv.insert("",'end', values=('PF00024','NGỤY NGỌC ','DUYÊN ','Production', 'Binh Phuoc', ' 8/20/1993', \
                             '0398586790', ' 5/25/2020', ' 6/25/2020', ))
trv.insert("",'end', values=('PF00003','LÊ THỊ MỸ ','DUYÊN ','Production', 'Gia Lai', ' 5/28/1988', \
                             '0169808888', ' 9/3/2020', ' 6/29/2020', ))
trv.insert("",'end', values=('PF00029','ĐINH THỊ ','HƯƠNG ','Production', 'Binh Dinh', ' 6/22/1989', \
                             '0368895956', ' 6/29/2020', ' 3/7/2020', ))
trv.insert("",'end', values=('PF00031','LÊ NGỌC ','QUYÊN  ','Sale& Marketing', 'Quang Ngai', ' 7/14/1990', \
                             '0169699993', ' 7/10/2020', ' 7/11/2022', ))
trv.insert("",'end', values=('PF00032','TRẦN THỊ LỆ  ','HỒNG  ','Sale& Marketing', 'Hue', ' 5/22/1990', \
                             '0169777889', ' 7/10/2020', ' 7/11/2022', ))
trv.insert("",'end', values=('PF00033','TRẦN THỊ LỆ  ','HOA  ','Sale& Marketing', 'Quang Ngai', ' 5/22/1990', \
                             '0169777889', ' 7/10/2020', ' 7/11/2022', ))
trv.insert("",'end', values=('PF00014','PHÙNG THỊ HỒNG  ','NHƯ  ','Sale& Marketing', 'Quang Tri', ' 8/14/1992', \
                             '0368588357', ' 3/16/2020', ' 7/20/2022', ))
trv.insert("",'end', values=('PF00010','TRỊNH THỊ CẨM  ','NHUNG  ','QA/QC', 'Ha Noi', ' 9/15/1999', \
                             '0787834586', ' 3/5/2020', ' 5/20/2022', ))
trv.insert("",'end', values=('PF00012','ONG THI THU ','THẢO  ','QA/QC', 'Thai Binh', ' 4/6/1993', \
                             '0981234567', ' 3/5/2020', ' 5/20/2021', ))
trv.insert("",'end', values=('PF00010','NGUYỄN THI HẠNH','NGUYÊN  ','QA/QC', 'Tuyen Quang', ' 4/9/1991', \
                             '0977611564', ' 3/7/2020', ' 5/20/2021', ))
trv.insert("",'end', values=('PF00019','NÔNG THỊ THANH ','HANG ','QA/QC', 'Hai Phong', ' 6/8/1999', \
                             '0987654433', ' 8/3/2020', ' 5/20/2022', ))
trv.insert("",'end', values=('PF00025','TRINH THI CAM ','TU','QA/QC', 'DA NANG', ' 6/7/1998', \
                             '0980654403', ' 8/20/2020', ' 5/25/2021', ))
trv.insert("",'end', values=('PF00028','LÂM THỊ YẾN ','NHI','QA/QC', 'Quang Tri', ' 6/13/1998', \
                             '0369653269', ' 6/20/2020', ' 8/25/2021', ))
# Search
lbl=ttk.Label(wrapper2, text='Search')
lbl.pack(side=tk.LEFT, padx=10)
ent=ttk.Entry(wrapper2, textvariable=var0)
ent.pack(side=tk.LEFT, padx=6)
btn=ttk.Button(wrapper2, text='Search', command=Search)
btn.pack(side=tk.LEFT, padx=6)
cbtn=ttk.Button(wrapper2, text='Clear', command=clear) 
cbtn.pack(side=tk.LEFT, padx=6)

# Add Record Entry Boxes
Label1=ttk.Label(wrapper4, text='Employee ID')
Label1.grid(row=0, column=0, padx=3, pady=3)
Entry1=ttk.Entry(wrapper4, textvariable=var1)
Entry1.grid(row=0, column=1, padx=3, pady=3)

Label2=ttk.Label(wrapper4, text='First name')
Label2.grid(row=1, column=0, padx=3, pady=3 )
Entry2=ttk.Entry(wrapper4, textvariable=var2)
Entry2.grid(row=1, column=1, padx=3, pady=3)

Label3=ttk.Label(wrapper4, text='Last name')
Label3.grid(row=2, column=0, padx=3, pady=3)
Entry3=ttk.Entry(wrapper4, textvariable=var3)
Entry3.grid(row=2, column=1, padx=3, pady=3)

Label4=ttk.Label(wrapper4, text='Department')
Label4.grid(row=3, column=0, padx=5, pady=3)
Entry4=ttk.Entry(wrapper4, textvariable=var4)
Entry4.grid(row=3, column=1, padx=5, pady=3)

Label5=ttk.Label(wrapper4, text='Place of origin')
Label5.grid(row=4, column=0, padx=5, pady=3)
Entry5=ttk.Entry(wrapper4, textvariable=var5)
Entry5.grid(row=4, column=1, padx=5, pady=3)

Label6=ttk.Label(wrapper4, text='Date of birth')
Label6.grid(row=0, column=2, padx=5, pady=3)
Entry6=ttk.Entry(wrapper4, textvariable=var6)
Entry6.grid(row=0, column=3, padx=5, pady=3)

Label7=ttk.Label(wrapper4, text='Phone number')
Label7.grid(row=1, column=2, padx=5, pady=3)
Entry7=ttk.Entry(wrapper4, textvariable=var7)
Entry7.grid(row=1, column=3, padx=5, pady=3)

Label8=ttk.Label(wrapper4, text='Start date')
Label8.grid(row=2, column=2, padx=5, pady=3)
Entry8=ttk.Entry(wrapper4, textvariable=var8)
Entry8.grid(row=2, column=3, padx=5, pady=3)

Label9=ttk.Label(wrapper4, text='End date')
Label9.grid(row=3, column=2, padx=5, pady=3)
Entry9=ttk.Entry(wrapper4, textvariable=var9)
Entry9.grid(row=3, column=3, padx=5, pady=3)

update_btn=ttk.Button(wrapper4, text='Update', command=update_employee)
add_btn=ttk.Button(wrapper4, text='Add New', command=add_employee)
delete_btn=ttk.Button(wrapper4, text='Delete', command=delete_employee)
select_record_btn = ttk.Button(wrapper4, text="Show Entry Boxes", command=show_entries)
clear_btn = ttk.Button(wrapper4, text="Clear Entry Boxes", command=clear_entries)

update_btn.grid(row=5, column=1, padx=5, pady=3)
add_btn.grid(row=5, column=0, padx=5, pady=3)
delete_btn.grid (row=5, column=2, padx=5, pady=3)     
select_record_btn.grid(row=5, column=3, padx=5, pady=3)
clear_btn.grid(row=5, column=4, padx=5, pady=3)


root.mainloop()
